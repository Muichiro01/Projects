# %% [markdown]
# <a href="https://colab.research.google.com/github/Muichiro01/Projects/blob/main/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=12
c=0
if a and b and c:
  print("All numbers have boolean have true")
else:
  print("Atleast one number has boolean value as false")
a=10
b=-10
c=0
if a or b or c:
  print("Atleast one number has a boolean value as true")
else:
  print("All the numbers have boolean value as false")
# Out:
# Atleast one number has boolean value as false
# Atleast one number has a boolean value as true

# %%
a=10
b=12
c=12
print(not (a==b))
print(not (b==c))
a="python"
b="coding"
if not (a==b):
  print("Hello")
a=4
b=5
if not ((a==1)==(b==5)):
  print("Hello")
a=int(input("Enter a number"))
if not (a%2==0):
  print(a," is an odd number")

# %%
h=float(input("Enter your height"))
w=float(input("Enter your weight"))
BMI=w/(h/100)**2
if BMI<=18.4:
  print("You are underweight")
elif BMI<=24.9:
  print("You are healthy")
elif BMI<=29.9:
  print("You are overweight")
elif BMI<=34.9:
  print("You are severely overweight")
elif BMI<=39.9:
  print("You are obese")
else:
  print("You are severely obese")
